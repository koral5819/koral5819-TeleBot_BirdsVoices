# %%
import requests as rq
# Конечная точка сайта с голосами птиц для России
url = "https://www.xeno-canto.org/api/2/recordings?query=cnt:Russian"
# Загрузка информации о птицах, представленных на сайте для России
response = rq.get(url, auth=('koral5819@yandex.ru', 'D#-R723wLcV'), allow_redirects=True)
# Получаем статус ответа, если 200 - запрос выполнен успешно
response.status_code
# Out:
# 200

# %%
# получаем json данные
json = response.json()
print(json)
# Out:
# {'numRecordings': '14742', 'numSpecies': '512', 'page': 1, 'numPages': 30, 'recordings': [{'id': '502758', 'gen': 'Tetrastes', 'sp': 'bonasia', 'ssp': '', 'en': 'Hazel Grouse', 'rec': 'Sergey Yurev', 'cnt': 'Russian Federation', 'loc': 'Permskiy Rayon, Perm Krai', 'lat': '57.8728', 'lng': '56.5561', 'alt': '150', 'type': 'call, female', 'url': '//xeno-canto.org/502758', 'file': 'https://xeno-canto.org/502758/download', 'file-name': 'XC502758-Tetrastes bonasia female2.mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/UCKAELIRCI/ffts/XC502758-small.png', 'med': '//xeno-canto.org/sounds/uploaded/UCKAELIRCI/ffts/XC502758-med.png', 'large': '//xeno-canto.org/sounds/uploaded/UCKAELIRCI/ffts/XC502758-large.png', 'full': '//xeno-canto.org/sounds/uploaded/UCKAELIRCI/ffts/XC502758-full.png'}, 'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/', 'q': 'A', 'length': '0:43', 'time': '14:00', 'date': '2018-09-27', 'uploaded': '2019-10-16', 'also': [''], 'rmk': '', 'bird-seen': 'unknown',
# ...

# %%
request.url
# Out:
# 'https://xeno-canto.org/api/2/recordings?query=cnt:Russian'

# %%
request.path_url
# Out:
# '/api/2/recordings?query=cnt:Russian'

# %%
request.method
# Out:
# 'GET'

# %%
request.headers
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
response.text
# Out:
# '{"numRecordings":"14742","numSpecies":"512","page":1,"numPages":30,"recordings":[{"id":"502758","gen":"Tetrastes","sp":"bonasia","ssp":"","en":"Hazel Grouse","rec":"Sergey Yurev","cnt":"Russian Federation","loc":"Permskiy Rayon, Perm Krai","lat":"57.8728","lng":"56.5561","alt":"150","type":"call, female","url":"\\/\\/xeno-canto.org\\/502758","file":"https:\\/\\/xeno-canto.org\\/502758\\/download","file-name":"XC502758-Tetrastes bonasia female2.mp3","sono":{"small":"\\/\\/xeno-canto.org\\/sounds\\/uploaded\\/UCKAELIRCI\\/ffts\\/XC502758-small.png","med":"\\/\\/xeno-canto.org\\/sounds\\/uploaded\\/UCKAELIRCI\\/ffts\\/XC502758-med.png","large":"\\/\\/xeno-canto.org\\/sounds\\/uploaded\\/UCKAELIRCI\\/ffts\\/XC502758-large.png","full":"\\/\\/xeno-canto.org\\/sounds\\/uploaded\\/UCKAELIRCI\\/ffts\\/XC502758-full.png"},"lic":"\\/\\/creativecommons.org\\/licenses\\/by-nc-sa\\/4.0\\/","q":"A","length":"0:43","time":"14:00","date":"2018-09-27","uploaded":"2019-10-16","also":[""],"rmk":"","bir
# ...

# %%
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Access-Control-Allow-Headers': 'DNT, User-Agent, X-Requested-With, If-Modified-Since, Cache-Control, Content-Type, Range, Authorization', 'Access-Control-Allow-Methods': 'GET, POST, OPTIONS', 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'Content-Length, Content-Range', 'Allow': 'GET, POST, OPTIONS', 'Cache-Control': 'max-age=0, private, must-revalidate, no-cache, private', 'Content-Encoding': 'gzip', 'Content-Type': 'application/json', 'Date': 'Wed, 28 Sep 2022 11:38:04 GMT', 'Server': 'nginx/1.23.1', 'Set-Cookie': 'PHPSESSID=op430q1b8bn8nl7e3ommd1n690; path=/', 'Vary': 'Accept-Encoding', 'X-Frame-Options': 'sameorigin', 'X-Powered-By': 'PHP/7.4.30', 'Transfer-Encoding': 'chunked'}

# %%
response.request.headers
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
response.json()

# %%
resp_sound = rq.get('https://xeno-canto.org/502758/download')
resp_sound.text
# Out:
# 'ID3\x04\x00\x00\x00\x00\x1fvTIT2\x00\x00\x00!\x00\x00\x00Hazel Grouse (Tetrastes bonasia)TCON\x00\x00\x00\x0c\x00\x00\x00PhasianidaeTPE1\x00\x00\x00\r\x00\x00\x00Sergey YurevTALB\x00\x00\x00\x0b\x00\x00\x00xeno-cantoTIT1\x00\x00\x00\x07\x00\x00\x00ibdvimCOMM\x00\x00\x01\x0f\x00\x00\x00eng\x00XC502758 © Sergey Yurev // Permskiy Rayon, Perm Krai (57.8728, 56.5561), Russian Federation // 150m // 14:00h, 2018-09-27 // call, femaleWCOP\x00\x00\x00\x11\x00\x002018 Sergey YurevWOAF\x00\x00\x00\x17\x00\x00//xeno-canto.org/502758\x0
# ...
