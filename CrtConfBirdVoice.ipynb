# %%
import configparser

from google.colab import drive
drive.mount('/content/drive')

config = configparser.ConfigParser()
config['URL'] = {
    'obj_url': 'https://www.xeno-canto.org/api/2/recordings?query=cnt:Russian',
    'wikiEndPoint': 'https://ru.wikipedia.org/api/rest_v1/page/',
}
config['ACCESS'] = {
    'username': 'koral5819@yandex.ru',
    'password': 'D#-R723wLcV',
}
config['KEY'] = {
    'bot_token': '5621803997:AAGsNlOxN6rfxkFS_18TzcnTpmf6LWAa0mc',
}
with open('/content/drive/MyDrive/School21/day08/birdVoice_py.ini', 'w') as configfile:
  config.write(configfile)
# Out:
# Mounted at /content/drive
